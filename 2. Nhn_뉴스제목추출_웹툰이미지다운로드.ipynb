# %% [markdown]
# ### 네이버 Papago 서비스 사용
# * 파이썬 기본 urllib 라이브러리 사용

# %%
# 네이버 Papago NMT API 예제
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin # url join하는 모듈

url = 'https://news.naver.com/'
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

res = requests.get(url, headers=req_header)
print(res.status_code)
# print('응답 헤더', res.headers)
# print('요청 헤더', res.request.headers)

if res.ok:
    # 응답객체에서 텍스트를 추출
    html = res.text
    # 추출한 텍스트를 파싱하기 위해 BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')
    
    atag_list = soup.select("a[href*='read.nhn']")
    print(type(atag_list))
    print(len(atag_list))
    
    for idx, atag in enumerate(atag_list, 1):
        title = atag.text.strip() # strip : 공백 없애주는 함수
        link = urljoin(url, atag['href'])
        
        print('{}, {}, {}'.format(idx, title, link))
# Out:
# 200
# <class 'bs4.element.ResultSet'>
# 186
# 1, 신규확진 119명 휴일임에도 세자리…요양병원-발…, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011969577
# 2, 독감 백신 접종…주의점과 이상징후 구별법[출…, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=422&aid=0000453894
# 3, 공수처 최후통첩 D-day···이낙연 "野 악용 좌시않을것", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003815933
# 4, 故 이건희 회장 오늘 입관식…삼성 사장단도 조문 예정(종합), https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=421&aid=0004949467
# 5, 주호영, 최재성 만나 "文대통령, 100일 지나도 답 없어…불통 심하다", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000608773
# 6, 추미애, 윤석열에 반격 나서나…안철수 "화해하기엔 선 넘었다", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=015&aid=0004437689
# 7, `구하라법`은 언제쯤…28년 만에 나타나 딸 유산 다 챙긴 생모, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=009&aid=0004681771
# 8, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=023&aid=0003571365
# 9, 두 나라 전쟁중인데… ‘세습독재’ 아제르바이잔만 돕겠다는 文정부, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=023&aid=0003571365
# 10, 박용진 "난 삼성저격수 아닌 지킴이…이재용과 삼성은 분리해 봐야", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=008&aid=0004489692
# 11, 이낙연, 이건희 '공과' 지적하자 "이 정도로 타락했나"·"내로남불" 쏟아진 비판, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003815959
# 12, 깎이고 무너지고…軍 전방 고지, 산사태 예방은?, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=056&aid=0010922770
# 13, [단독]이란 주재 北외교관, 테헤란~두바이 오가며 달러·금 밀거래, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=023&aid=0003571364
# 14, 이낙연 "이건희, 그늘도 남겼다" 애도에 "안 하느니만 못해", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=629&aid=0000048520
# 15, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=001&aid=0011969689
# 16, 한진, 택배업계 처음으로 심야배송 전면 중단…다음달 시행, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=001&aid=0011969689
# 17, 선대와는 다른 길?…이재용·이부진·이서현 각자경영 이어갈 듯, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=016&aid=0001742503
# 18, 이건희 장례식장에서 가장 주목 받는 사람은?...‘손녀’, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=023&aid=0003571368
# 19, 현대건설, 올해 도시정비사업 수주 4조4천억원…역대 최대 눈앞, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=001&aid=0011969682
# 20, 윤석헌 금융감독원장, 시중은행장 만난다…신용대출·금융지원 논의할듯, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=029&aid=0002632254
# 21, 구직자 10명 중 7명은 '취업 사교육' 필요 "불안해서", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=008&aid=0004489696
# 22, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004949582
# 23, "나 버리고 갔잖아" 헤어진 연인 성폭행 40대 징역 3년6개월, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004949582
# 24, ‘경남 코로나19’ 제사 다녀간 창원 일가친척 6명 확진, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=032&aid=0003039531
# 25, 성일종 “모친 전재산 9만원? 전두환이냐” vs 조국 “가족 경제 파탄”, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=005&aid=0001374334
# 26, 독감 백신 '논란'을 멈추라, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=002&aid=0002156132
# 27, 주말 효과 없이...26일 코로나19 신규 확진자 119명, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=002&aid=0002156131
# 28, 경기도, 23개 시·군 외국인·법인 토지거래허가구역 지정, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=003&aid=0010147053
# 29, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=296&aid=0000046925
# 30, 신규확진 119명, “검사 수 줄었는데 환자는 크게 증가”, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=296&aid=0000046925
# 31, 누구나 한 번쯤 경험하는 손 떨림… ‘위험신호’일 때는?, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=346&aid=0000034825
# 32, 엔카닷컴 “제네시스 G70, 9월 국산차 검색어 1위”…2위는 아반떼, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004681882
# 33, “한국서 돈·명예 얻고 역사왜곡”…中아이돌 ‘활동 제재’ 청원[이슈픽], https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=081&aid=0003134182
# 34, “계절독감으로 한해 3천여 명 사망”… 예방접종 안전하게 받으려면?, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=056&aid=0010922747
# 35, 코로나 이후 미래를 좌우할 비즈니스는 무엇일까?, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002289347
# 36, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=016&aid=0001742495
# 37, 외신들 “삼성을 세계적 거인으로”…IOC는 조기 게양, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=016&aid=0001742495
# 38, "스가, 징용문제 조건은 자기모순...한중일 정상회담 참석해야", https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=011&aid=0003815957
# 39, “미중 충돌 최악 시나리오도 준비”…중국 6·25 70주년 전시 성황, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=081&aid=0003134180
# 40, '공항 화장실에 버려진 아이' 카타르, 여성승객 강제 자궁 검사, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011969586
# 41, 유럽 ‘봉쇄 수준’ 고강도 조치…반발 시위 잇따라, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=056&aid=0010922743
# 42, "생리 한다고 다 여자 아냐"…성소수자 옹호도 좋지만, '뿔난' 여성들, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=008&aid=0004489651
# 43, , https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=031&aid=0000564506
# 44, "에어팟·갤버라 비켜!"…LG전자, '노캔' 무선이어폰으로 재기 노린다, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=031&aid=0000564506
# 45, [이건희 별세]"갤럭시에 올인하라"…세계 1위 스마트폰 신화 이 한마디에서 시작, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=016&aid=0001742474
# 46, 스페이스X, 100번째 로켓 발사 성공, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=092&aid=0002202941
# 47, 언택트·脫통신 효과...이통사 3분기 '선방', https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=277&aid=0004779275
# 48, LG헬로비전, 유심가입자 30% 편의점 선택했다, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=014&aid=0004516816
# 49, 국감 종료 30분전 이원욱 위원장은 왜 폭발했나, https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=138&aid=0002093594
# 50, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=056&aid=0010922718&rankingType=RANKING
# 51, 국내 신규 확진자 119명으로 세 자릿수…경기 65명·서울 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=056&aid=0010922718&rankingType=RANKING
# 52, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=011&aid=0003815855&rankingType=RANKING
# 53, '5,000만원이면 수도권 아파트 사는데'···전세난에 ' …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=011&aid=0003815855&rankingType=RANKING
# 54, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=082&aid=0001037953&rankingType=RANKING
# 55, [속보] "부작용 비해 접종 이익 훨씬 커"…오늘부터 만  …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=082&aid=0001037953&rankingType=RANKING
# 56, 동영상기사, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=052&aid=0001506389&rankingType=RANKING
# 57, 정·재계 조문 줄 이을 듯...잠시 뒤 故 이건희 삼성그룹 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=052&aid=0001506389&rankingType=RANKING
# 58, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=123&aid=0002232988&rankingType=RANKING
# 59, [날씨] 맑고 일교차 커…수도권 미세먼지 일시 '나쁨', https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=123&aid=0002232988&rankingType=RANKING
# 60, 동영상기사, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=448&aid=0000309762&rankingType=RANKING
# 61, 예쁘다고 심었는데 '생태계 위협'…제주 핑크뮬리밭 갈아엎어, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=448&aid=0000309762&rankingType=RANKING
# 62, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=015&aid=0004437366&rankingType=RANKING
# 63, 부동산 세금 큰 파도 온다…"집 팔려면 올해 넘기지 마라", https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=015&aid=0004437366&rankingType=RANKING
# 64, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=053&aid=0000028118&rankingType=RANKING
# 65, 차기 美 행정부의 세계 경영 ‘대전략’ 선택지, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=053&aid=0000028118&rankingType=RANKING
# 66, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=002&aid=0002156115&rankingType=RANKING
# 67, 美하원서 발의돼 51명 서명한 한국전 종전선언 결의안, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=002&aid=0002156115&rankingType=RANKING
# 68, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=028&aid=0002517645&rankingType=RANKING
# 69, 서울~부산을 50분에?…시속 500km 하이퍼카 등장, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=028&aid=0002517645&rankingType=RANKING
# 70, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=469&aid=0000547588&rankingType=RANKING
# 71, 이건희가 유년시절 사랑했던 4가지... 영화, 운동, 자동 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=469&aid=0000547588&rankingType=RANKING
# 72, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=586&aid=0000017728&rankingType=RANKING
# 73, 이재용 지분 상속의 핵심 '삼성생명' 주식 어떻게?, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=586&aid=0000017728&rankingType=RANKING
# 74, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=081&aid=0003134167&rankingType=RANKING
# 75, 암투병에도 연락없던 엄마…사망하자 “보험금 나눠달라”, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=081&aid=0003134167&rankingType=RANKING
# 76, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=023&aid=0003571242&rankingType=RANKING
# 77, “돈은 한국서 벌면서 역사왜곡, 빅토리아·레이 활동 중단” …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=023&aid=0003571242&rankingType=RANKING
# 78, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=001&aid=0011969261&rankingType=RANKING
# 79, 제2의 '구하라 사건'…딸 숨지자 28년만에 나타난 생모, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=001&aid=0011969261&rankingType=RANKING
# 80, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=009&aid=0004681580&rankingType=RANKING
# 81, 호텔신라 주변 낙후동네 바라보며…"어린이집 만들라", https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=009&aid=0004681580&rankingType=RANKING
# 82, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=020&aid=0003316548&rankingType=RANKING
# 83, 이재용 부회장, 아들·딸과 故이건희 회장 빈소 도착, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=020&aid=0003316548&rankingType=RANKING
# 84, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=262&aid=0000013889&rankingType=RANKING
# 85, 행실 무개념 연예인 Top3? 조회수 목맨 ‘이슈 유튜버’, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=262&aid=0000013889&rankingType=RANKING
# 86, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=449&aid=0000199437&rankingType=RANKING
# 87, 코로나19 어제 신규확진자 119명…국내발생만 94명, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=449&aid=0000199437&rankingType=RANKING
# 88, [속보] 코로나19 119명 신규확진, 다시 세자리…지역 94명·해외 25명, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=437&aid=0000250617&rankingType=RANKING
# 89, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=014&aid=0004516788&rankingType=RANKING
# 90, 컵라면이 뭐라고...산에서 긴 줄, 울산시 점검 나서, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=014&aid=0004516788&rankingType=RANKING
# 91, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=005&aid=0001374268&rankingType=RANKING
# 92, [포착] 부친 임종지킨 이재용, 장례식장까지 직접 운전, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=005&aid=0001374268&rankingType=RANKING
# 93, [속보] "백신 맞고 응급실행"…경산·예천서 독감백신 접종 2명 사망, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=277&aid=0004779206&rankingType=RANKING
# 94, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=032&aid=0003039523&rankingType=RANKING
# 95, [속보] 코로나19 신규 확진자 119명…다시 세자릿수로, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=032&aid=0003039523&rankingType=RANKING
# 96, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=055&aid=0000850296&rankingType=RANKING
# 97, 제2의 '구하라 사건'…딸 숨지자 28년 만에 나타난 생모, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=055&aid=0000850296&rankingType=RANKING
# 98, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=003&aid=0010146745&rankingType=RANKING
# 99, 文대통령 지지율, 45.6%…민주당 35.1% 국민의힘 2 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=003&aid=0010146745&rankingType=RANKING
# 100, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=629&aid=0000048406&rankingType=RANKING
# 101, 로또 934회 당첨번호 1등 4명…'역대급 57억 받는다', https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=629&aid=0000048406&rankingType=RANKING
# 102, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=346&aid=0000034821&rankingType=RANKING
# 103, “소리 없이 찾아오는 뇌동맥류… 터진 후에 오면 사망 위험 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=346&aid=0000034821&rankingType=RANKING
# 104, 동영상기사, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=057&aid=0001512548&rankingType=RANKING
# 105, 오늘부터 62~69세 접종…"독감 백신, 사망과 인과성 극 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=057&aid=0001512548&rankingType=RANKING
# 106, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=087&aid=0000818197&rankingType=RANKING
# 107, 이재용, 故 이건희 회장 장례로 '국정농단' 재판 불출석할 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=087&aid=0000818197&rankingType=RANKING
# 108, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=293&aid=0000031505&rankingType=RANKING
# 109, [SNS에세이]日언론 “유니클로 히트텍, 한국인 필수품”… …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=293&aid=0000031505&rankingType=RANKING
# 110, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=119&aid=0002437684&rankingType=RANKING
# 111, 나경원 '집중 공세'하며 증인으론 못 부르는 민주당…"뭐가 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=119&aid=0002437684&rankingType=RANKING
# 112, 동영상기사, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=374&aid=0000223774&rankingType=RANKING
# 113, [오늘 기업 오늘 사람] 삼성전자·삼성생명·삼성물산·르노삼 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=374&aid=0000223774&rankingType=RANKING
# 114, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=022&aid=0003516433&rankingType=RANKING
# 115, ‘제2의 구하라 사건’ 또… 28년 만에 나타난 생모, 전 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=022&aid=0003516433&rankingType=RANKING
# 116, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=421&aid=0004949299&rankingType=RANKING
# 117, 故 이건희 회장 오늘 입관식…삼성 사장단도 조문 예정, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=421&aid=0004949299&rankingType=RANKING
# 118, 동영상기사, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=214&aid=0001075224&rankingType=RANKING
# 119, 오늘 이건희 회장 입관식…이 시각 빈소, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=214&aid=0001075224&rankingType=RANKING
# 120, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid
://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=296&aid=0000046921&rankingType=RANKING
# 155, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=152&aid=0001960702&rankingType=RANKING
# 156, “삼성의 어두운 역사, 이건희의 죽음과 함께 끝나야”, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=152&aid=0001960702&rankingType=RANKING
# 157, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=007&aid=0000006621&rankingType=RANKING
# 158, “성매매는 당사자 여성들에게 언제나 경제문제였다”, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=007&aid=0000006621&rankingType=RANKING
# 159, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000028435&rankingType=RANKING
# 160, K-배터리 판결 앞두고 날카로운 신경전, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000028435&rankingType=RANKING
# 161, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=029&aid=0002632219&rankingType=RANKING
# 162, 이근, 이번엔 핼러윈 조커 분장…"왜 그리 심각해", https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=029&aid=0002632219&rankingType=RANKING
# 163, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=044&aid=0000222721&rankingType=RANKING
# 164, Architect of Samsung’s tech revo …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=044&aid=0000222721&rankingType=RANKING
# 165, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=047&aid=0002289334&rankingType=RANKING
# 166, 한국은 되고 유럽은 안 되는 이유, '가디언'의 적나라한  …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=047&aid=0002289334&rankingType=RANKING
# 167, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=366&aid=0000608662&rankingType=RANKING
# 168, [시승기] 갖출 것 다 갖춘 2000만원대 전기차, 푸조  …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=366&aid=0000608662&rankingType=RANKING
# 169, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003423133&rankingType=RANKING
# 170, "엄마, 나 구글 기프트카드 사줘"는 전형적인 '보이스 피 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003423133&rankingType=RANKING
# 171, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000910406&rankingType=RANKING
# 172, "삼성그룹주 배당 커질 듯"…상속세 10조 마련해야, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000910406&rankingType=RANKING
# 173, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000081441&rankingType=RANKING
# 174, 길 가는 여성 폭행한 남성 "아는 사람"이라며 풀어준 경찰 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000081441&rankingType=RANKING
# 175, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002202904&rankingType=RANKING
# 176, 中 비보, 6G 개발 시작...4대 모바일 기업 '6G 레 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002202904&rankingType=RANKING
# 177, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003423133&rankingType=RANKING
# 178, "엄마, 나 구글 기프트카드 사줘"는 전형적인 '보이스 피 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003423133&rankingType=RANKING
# 179, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000910406&rankingType=RANKING
# 180, "삼성그룹주 배당 커질 듯"…상속세 10조 마련해야, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000910406&rankingType=RANKING
# 181, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000081441&rankingType=RANKING
# 182, 길 가는 여성 폭행한 남성 "아는 사람"이라며 풀어준 경찰 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000081441&rankingType=RANKING
# 183, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002202904&rankingType=RANKING
# 184, 中 비보, 6G 개발 시작...4대 모바일 기업 '6G 레 …, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002202904&rankingType=RANKING
# 185, , https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=036&aid=0000043874&rankingType=RANKING
# 186, AI 면접관이 말했다 “너 인성 문제 있어?”, https://news.naver.com/main/ranking/read.nhn?mode=LSD&mid=shm&sid1=001&oid=036&aid=0000043874&rankingType=RANKING

# %% [markdown]
# ### 웹툰 이미지 다운로드

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail.nhn?titleId=735661&no=53&amp;weekday=fri'
}

img_urls = [
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_1.jpg',
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_2.jpg',
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_3.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
    if res.ok:
        #응답객체에서 binary(이진) 데이터를 가져올때는 content 속성을 사용한다
        img_data = res.content
        #img_url에서 file 이름만 꺼내기
        file_name = os.path.basename(img_url)
        #print(file_name)
        #binary 데이터를 file로 저장하기 
        with open(file_name,'wb') as file:
            print(f'Writing to {file_name} ({len(img_data)}) bytes')
            file.write(img_data)
# Out:
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_1.jpg (112100) bytes
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_2.jpg (216632) bytes
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_3.jpg (135534) bytes

# %% [markdown]
# ### 특정 웹툰 페이지의 모든 image를 다운로드 받기
# * soup.select("img[src$='jpg']")
# * img 폴더를 생성하고 그 아래에 파일을 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

main_url = 'https://comic.naver.com/webtoon/detail.nhn?titleId=712362&no=94&amp;weekday=fri'
res = requests.get(main_url)
print(res.status_code)
if res.ok:
    html = res.text
    soup = BeautifulSoup(html,'html.parser')
    
    print(len(soup.select("img[src$='.jpg']")))
    img_url_list = []
    for img_url in soup.select("img[src$='jpg']"):
        img_url_list.append(img_url['src'])

img_url_list[0:3]
# Out:
# 200
# 57
# ['https://shared-comic.pstatic.net/thumb/webtoon/712362/thumbnail/thumbnail_IMAG04_ac694463-dc14-4362-b66d-8f20ee06017d.jpg',
#  'https://image-comic.pstatic.net/webtoon/712362/94/20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_1.jpg',
#  'https://image-comic.pstatic.net/webtoon/712362/94/20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_2.jpg']

# %%
#img 디렉토리 생성
#img 디렉토리가 없으면
if not os.path.isdir('img'):
    os.mkdir('img')

# %%
#image_url_list에 있는 url로 요청해서 image들을 다운로드 하기
for idx,img_url in enumerate(img_url_list,1):
    print(f'---> 다운로드 번호 {idx}')
    req_header = {
        'referer':main_url
    }
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_name = os.path.basename(img_url)
        with open('img/'+file_name,'wb') as file:
            print(f'파일명 :{file_name} ({len(img_data)}) bytes')
            file.write(img_data)
# Out:
# ---> 다운로드 번호 1
# 파일명 :thumbnail_IMAG04_ac694463-dc14-4362-b66d-8f20ee06017d.jpg (32102) bytes
# ---> 다운로드 번호 2
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_1.jpg (120839) bytes
# ---> 다운로드 번호 3
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_2.jpg (102260) bytes
# ---> 다운로드 번호 4
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_3.jpg (156656) bytes
# ---> 다운로드 번호 5
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_4.jpg (73441) bytes
# ---> 다운로드 번호 6
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_5.jpg (99572) bytes
# ---> 다운로드 번호 7
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01
# 파일명 :thumbnail_202x120_037fbd56-d472-40fa-8bf9-4af7966c8179.jpg (30054) bytes
# ---> 다운로드 번호 52
# 파일명 :thumbnail_202x120_943cfc31-3cf6-48d8-96bf-e0bd532764c7.jpg (42612) bytes
# ---> 다운로드 번호 53
# 파일명 :title_thumbnail_014542_125x101.jpg (4512) bytes
# ---> 다운로드 번호 54
# 파일명 :thumbnail_IMAG10_d093ab2d-a006-457b-92b5-1da097bc3af1.jpg (13133) bytes
# ---> 다운로드 번호 55
# 파일명 :thumbnail_IMAG10_bea8fafc-f043-4712-97e7-f9dbc5c61dcb.jpg (14696) bytes
# ---> 다운로드 번호 56
# 파일명 :title_thumbnail_20160601180804_t83x90.jpg (4436) bytes
# ---> 다운로드 번호 57
# 파일명 :thumbnail_IMAG10_34e13db4-712c-4556-9e32-5ecf17061293.jpg (11052) bytes

# %%
def download_image(title, url):
    import requests
    from bs4 import BeautifulSoup 
    import os
    
    req_header = {
        'referer':url
    }
    
    res = requests.get(url)
    print(res.status_code)
    
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        
        imgurl_list = list()
        
        for img_tag in soup.select('img[src$=".jpg"]'):
            imgurl_list.append(img_tag['src'])
            
        dir_name = 'img/' + title
        if not os.path.isdir(dir_name):
            os.mkdir(dir_name)
            
        for idx, img_url in enumerate(imgurl_list, 1):
            # header가 없으면 다운로드 받을 수 없음
            res = requests.get(img_tag['src'], headers=req_header)
            if res.ok:
                img_data = res.content
                file_name = os.path.basename(img_url)
                file_name = dir_name + '/' + file_name
                with open(file_name, 'wb') as file:
                    file.write(img_data)
        
download_image('약한영웅', 'https://comic.naver.com/webtoon/detail.nhn?titleId=710751&no=125&weekday=sun')
# Out:
# 200

# %% [markdown]
# ### 네이버 웹툰 홈에서 추천웹툰의 제목과 url 알아내기

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

main_url = 'https://comic.naver.com/index.nhn'

res = requests.get(main_url)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')    
    recom_webtoon_list = []
    
    for div_tag in soup.select('div.genreRecomInfo2'):
        recom_webtoon_dict = {}
        a_tag1 = div_tag.select('h6 a')[0]
        title = a_tag1.text.strip() # 웹툰 제목
        webtoon_url = urljoin(main_url, a_tag1['href']) # 웹툰 url
        
        a_tag2 = div_tag.select('p a')[0] # 웹툰의 회차 url
        webtoon_episode_url = urljoin(main_url, a_tag2['href'])

        print(div_tag)
        recom_webtoon_dict['title'] = title
        recom_webtoon_dict['webtoon_url'] = webtoon_url
        recom_webtoon_dict['episode_url'] = webtoon_episode_url
        
        recom_webtoon_list.append(recom_webtoon_dict)
    #print(recom_webtoon_list)
# Out:
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=754781" onclick="nclk_v2(event,'rcn*s.title','754781','1')">
# <span>바이러스X</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=754781&amp;no=2" onclick="nclk_v2(event,'rcn*s.sub','754781','1')">
# <span>2화. 바이러스X(2)</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('754781', '1', this, event);">
#
#
# 								준 / 하랑
#
# 							</a>
# </span>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=742889" onclick="nclk_v2(event,'rcn*s.title','742889','2')">
# <span>노력의 결과</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=742889&amp;no=32" onclick="nclk_v2(event,'rcn*s.sub','742889','2')">
# <span>후기</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('742889', '2', this, event);">
#
# 								악파
#
#
# 							</a>
# </span>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=733074" onclick="nclk_v2(event,'rcn*s.title','733074','3')">
# <span>백수세끼</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=733074&amp;no=60" onclick="nclk_v2(event,'rcn*s.sub','733074','3')">
# <span>60화 컵라면과 삼각김밥</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('733074', '3', this, event);">
#
# 								치즈
#
#
# 							</a>
# </span>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=687915" onclick="nclk_v2(event,'rcn*s.title','687915','4')">
# <span>꿈의 기업</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=687915&amp;no=205" onclick="nclk_v2(event,'rcn*s.sub','687915','4')">
# <span>4부 62화</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('687915', '4', this, event);">
#
# 								문지현
#
#
# 							</a>
# </span>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=737378" onclick="nclk_v2(event,'rcn*s.title','737378','5')">
# <span>블루투스</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=737378&amp;no=46" onclick="nclk_v2(event,'rcn*s.sub','737378','5')">
# <span>46화</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('737378', '5', this, event);">
#
# 								국승원
#
#
# 							</a>
# </span>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_smart" style="display:none;">스마트툰</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list.nhn?titleId=734918" onclick="nclk_v2(event,'rcn*s.title','734918','6')">
# <span>모락모락 왕세자님</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail.nhn?titleId=734918&amp;no=56" onclick="nclk_v2(event,'rcn*s.sub','734918','6')">
# <span>56화</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('734918', '6', this, event);">
#
# 								원해
#
#
# 							</a>
# </span>
# </div>

# %% [markdown]
# ### 6개의 만화의 제목과 회차url을 꺼내서 download_image() 함수 호출

# %%
for idx, webtoon in enumerate(recom_webtoon_list, 1):
    print('--->> {}. {}'.format(idx, webtoon['title']))
    download_image(webtoon['title'], webtoon['episode_url'])
# Out:
# --->> 1. 바이러스X
# 200
# --->> 2. 노력의 결과
# 200
# --->> 3. 백수세끼
# 200
# --->> 4. 꿈의 기업
# 200
# --->> 5. 블루투스
# 200
# --->> 6. 모락모락 왕세자님
# 200
